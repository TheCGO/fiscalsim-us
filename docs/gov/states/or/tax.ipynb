# %% [markdown]
# # Oregon state income tax
#
# This notebook shows how Oregon's state income tax, including credits, operates holistically.
#
# ## Examples

# %%
from fiscalsim_us import IndividualSim
import pandas as pd
import plotly.express as px

LIGHT_GRAY = "#F5F5F5"
GRAY = "#BDBDBD"
BLUE = "#5091cc"
LIGHT_BLUE = "lightblue"
DARK_BLUE = "darkblue"


def make_tax(adults, children):
    sim = IndividualSim(year=2022)
    sim.add_person(name="head", age=25)
    members = ["head"]
    if adults == 2:
        sim.add_person(name="spouse", age=25)
        members += ["spouse"]
    for i in range(children):
        child = "child{}".format(i)
        sim.add_person(name=child, age=6)
        members += [child]
    sim.add_tax_unit(name="tax_unit", members=members, premium_tax_credit=0)
    sim.add_household(name="household", members=members, state_code="OR")
    sim.vary("employment_income", max=300_000, step=100)
    employment_income = sim.calc("employment_income")[0]
    state_income_tax = sim.calc("state_income_tax")[0].round()
    mtr = sim.deriv("state_income_tax", "employment_income", wrt_target="head")
    return pd.DataFrame(
        dict(
            employment_income=employment_income,
            state_income_tax=state_income_tax,
            mtr=mtr,
            adults=adults,
            children=str(children),
        )
    )


# Make a table of state taxes for different numbers of adults and children.
l = []
for adults in range(1, 3):
    for children in range(0, 4):
        l.append(make_tax(adults, children))

df = pd.concat(l)

LABELS = dict(
    employment_income="Employment income",
    state_income_tax="Oregon tax",
    mtr="Marginal tax rate",
    adults="Adults",
    children="Children",
)

COLOR_MAP = {"0": GRAY, "1": LIGHT_BLUE, "2": BLUE, "3": DARK_BLUE}

fig = px.line(
    df,
    "employment_income",
    "state_income_tax",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Oregon state income tax",
    color_discrete_map=COLOR_MAP,
)
fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat="$,",
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6656\3166926098.py in <module>
# ----> 1 from fiscalsim_us import IndividualSim
#       2 import pandas as pd
#       3 import plotly.express as px
#       4
#       5 LIGHT_GRAY = "#F5F5F5"
#
# c:\users\patri\github\fiscalsim-us\fiscalsim_us\__init__.py in <module>
#       9 See https://openfisca.org/doc/key-concepts/tax_and_benefit_system.html
#      10 """
# ---> 11 from fiscalsim_us.system import (
#      12     CountryTaxBenefitSystem,
#      13     Simulation,
#
# c:\users\patri\github\fiscalsim-us\fiscalsim_us\system.py in <module>
#       2 from policyengine_core.taxbenefitsystems import TaxBenefitSystem
#       3 from fiscalsim_us.entities import *
# ----> 4 from fiscalsim_us.parameters.gov.irs.uprating import (
#       5     set_irs_uprating_parameter,
#       6 )
#
# c:\users\patri\github\fiscalsim-us\fiscalsim_us\parameters\__init__.py in <module>
#       2 from policyengine_core.parameters import ParameterNode
#       3
# ----> 4 default_parameters = ParameterNode(directory_path=Path(__file__).parent)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     112                     child_name_expanded = _compose_name(name, child_name)
#     113                     child = ParameterNode(
# --> 114                         child_name_expanded, directory_path=child_path
#     115                     )
#     116                     self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     104                         child_name_expanded = _compose_name(name, child_name)
#     105                         child = load_parameter_file(
# --> 106                             child_path, child_name_expanded
#     107                         )
#     108                         self.add_child(child_name, child)
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\helpers.py in load_parameter_file(file_path, name)
#      27         return parameters.ParameterNode(name, directory_path=file_path)
#      28     data = _load_yaml_file(file_path)
# ---> 29     return _parse_child(name, data, file_path)
#      30
#      31
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\helpers.py in _parse_child(child_name, child, child_path)
#      73     else:
#      74         return parameters.ParameterNode(
# ---> 75             child_name, data=child, file_path=child_path
#      76         )
#      77
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     133                 child_name = str(child_name)
#     134                 child_name_expanded = _compose_name(name, child_name)
# --> 135                 child = _parse_child(child_name_expanded, child, file_path)
#     136                 self.add_child(child_name, child)
#     137
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\helpers.py in _parse_child(child_name, child, child_path)
#      73     else:
#      74         return parameters.ParameterNode(
# ---> 75             child_name, data=child, file_path=child_path
#      76         )
#      77
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\parameter_node.py in __init__(self, name, directory_path, data, file_path)
#     133                 child_name = str(child_name)
#     134                 child_name_expanded = _compose_name(name, child_name)
# --> 135                 child = _parse_child(child_name_expanded, child, file_path)
#     136                 self.add_child(child_name, child)
#     137
#
# ~\anaconda3\envs\fiscalsim-us\lib\site-packages\policyengine_core\parameters\helpers.py in _parse_child(child_name, child, child_path)
#      63
#      64 def _parse_child(child_name, child, child_path):
# ---> 65     if "values" in child:
#      66         return parameters.Parameter(child_name, child, child_path)
#      67     elif "brackets" in child:
#
# TypeError: argument of type 'int' is not iterable

# %% [markdown]
# Total marginal tax rates range from -4.1% for filers in the EITC phase-in region to +10.6% to filers in the EITC phase-out region; this exceeds the 9.9% marginal tax rate on top earners.
# In addition, Oregon's tax system creates cliffs due to (a) income limits on the exemption credit, and (b) the step-down of the federal tax liability subtraction.

# %%
fig = px.line(
    df,
    "employment_income",
    "mtr",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Marginal tax rate for an Oregon household",
    color_discrete_map=COLOR_MAP,
)
fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat=".1%",
    yaxis_range=[-0.15, 0.15],
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()
